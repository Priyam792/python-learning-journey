# %% [markdown]
# # _**Core Data Structures in Pandas**_
# ---
# ---
# Pandas is built on two main data structures:
# - Series → One-dimensional (like a single column in Excel)
# - DataFrame → Two-dimensional (like a full spreadsheet or SQL table)
# ---
# # Series — 1D Labeled Array
# A Series is like a list with labels (index).

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30])

# %%
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# - Here the index assigned automatically
# - For defining custom index :

# %%
s.index = ['a','b','c']
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# - The diffrence between pandas.Series and python dictionary is :
# Unlike a dictionary, a Series supports fast vectorized operations, automatic index alignment during arithmetic, and handles missing data using NaN.

# %% [markdown]
# # DataFrame — 2D Labeled Table
# ---
# A DataFrame is like a dictionary of Series — multiple columns with labels.

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %% [markdown]
# - Each column in a DataFrame is a Series .
# ---
# # Changing index and coluumn's names

# %%
df.index = [1,2,3]
df.columns = ['Name','Age','City']
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
print(df)
# Out:
#       Name  Age       City
# 1    Alice   25      Delhi
# 2      Bob   30     Mumbai
# 3  Charlie   35  Bangalore

# %% [markdown]
# # Summary
# • Series = 1D array with labels
# • DataFrame = 2D table with rows + columns• Both come with index and are the heart of Pandas
